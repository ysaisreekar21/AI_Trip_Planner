# %%
from databricks.sdk import WorkspaceClient

w = WorkspaceClient()

for p in w.postgres.list_projects():
    display({
        "project_id": p.project_id,
        "name": p.name,
        "display_name": p.spec.display_name if p.spec else None,
        "default_branch": p.spec.default_branch if p.spec else None
    })
